# %%
import streamlit as st
import joblib
import numpy as np

model = joblib.load("walmart_model.pkl")

st.title("🛒 Walmart Sales Prediction")

store = st.number_input("Store", 1)
holiday = st.selectbox("Holiday Flag", [0, 1])
temp = st.number_input("Temperature")
fuel = st.number_input("Fuel Price")
cpi = st.number_input("CPI")
unemp = st.number_input("Unemployment")

year = st.number_input("Year", 2010)
month = st.number_input("Month", 1)
day = st.number_input("Day", 1)

if st.button("Predict"):
    data = np.array([[store, holiday, temp, fuel, cpi, unemp, year, month, day]])
    result = model.predict(data)
    st.success(f"Predicted Sales: {result[0]:,.2f}")
# Out:
# 2026-04-30 21:49:47.821 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:49:48.822
# ...
#   command:
#
#     streamlit run C:\Users\Lenovo\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-30 21:49:48.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:49:48.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:49:48.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:49:48.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-30 21:49:48.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
